# %%
import pandas as pd
import sqlalchemy as sa
import json
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Get database credentials from environment variables
host = os.getenv('POSTGRES_HOST')
port = os.getenv('POSTGRES_PORT', '5432')
database = os.getenv('POSTGRES_DATABASE')
user = os.getenv('POSTGRES_USER')
password = os.getenv('POSTGRES_PASSWORD')

# Load test cases from JSON
with open('mini_dev_postgresql_vds.json', 'r') as f:
    test_cases = json.load(f)

# Create a lookup dictionary by question_id for easy access
sql_queries = {tc['question_id']: tc for tc in test_cases}
print(f"Loaded {len(sql_queries)} test cases from JSON")

# %%
engine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}")

# %%
# Question ID 5
test_case = sql_queries[5]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 11
test_case = sql_queries[11]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 12
test_case = sql_queries[12]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 17
test_case = sql_queries[17]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 23
test_case = sql_queries[23]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 24
test_case = sql_queries[24]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 25
test_case = sql_queries[25]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(sa.text(test_case['SQL']), engine)
df

# %%
# Question ID 26
test_case = sql_queries[26]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 27
test_case = sql_queries[27]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 28
test_case = sql_queries[28]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 31
test_case = sql_queries[31]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 32
test_case = sql_queries[32]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 37
test_case = sql_queries[37]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 36
test_case = sql_queries[36]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 39
test_case = sql_queries[39]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 40
test_case = sql_queries[40]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 41
test_case = sql_queries[41]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 45
test_case = sql_queries[45]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 46
test_case = sql_queries[46]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 47
test_case = sql_queries[47]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 48
test_case = sql_queries[48]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 50
test_case = sql_queries[50]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 62
test_case = sql_queries[62]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 72
test_case = sql_queries[72]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 77
test_case = sql_queries[77]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 79
test_case = sql_queries[79]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 82
test_case = sql_queries[82]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 83
test_case = sql_queries[83]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 85
test_case = sql_queries[85]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df

# %%
# Question ID 87
test_case = sql_queries[87]
print(f"Question: {test_case['question']}")
print(f"Evidence: {test_case.get('evidence', 'N/A')}\n")

df = pd.read_sql(test_case['SQL'], engine)
df
